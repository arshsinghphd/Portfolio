# %%
from sklearn.datasets import load_iris

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
iris=load_iris()

# %%
X=iris.data[:,2:]

# %%
y=iris.target

# %% [markdown]
# # Decision Tree Classifier

# %%
tree_clf=DecisionTreeClassifier(max_depth=2)

# %%
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import export_graphviz

# %%
import os
from os import path

# %%
dir_path=os.getcwd()

# %%
fig_path=os.path.join(dir_path,"figures")
fig_path
# Out:
# 'C:\\Users\\arsha\\OneDrive\\LearningProgramming\\LearningML\\WorkForGeronCourse\\practice hml\\figures'

# %%
out_path=os.path.join(fig_path,"iris_tree.dot")

# %%
export_graphviz(tree_clf,
               out_file=out_path,
               feature_names=iris.feature_names[2:],
               class_names=iris.target_names,
               rounded=True,
               filled=True
               )

# %%
# !cd "C:\Users\arsha\OneDrive\LearningProgramming\LearningML\WorkForGeronCourse\practice hml\figures\"

# %%
# !dot -Tpng "figures\iris_tree.dot" -o "figures\iris_tree.png"

# %%
from IPython.display import Image

# %%
png_path=os.path.join(fig_path,'iris_tree.png')

# %%
Image(png_path)

# %%
tree_clf.predict_proba([[5,1.5]])
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
tree_clf.predict([[5,1.5]])
# Out:
# array([1])

# %%
tree_clf=DecisionTreeClassifier()

# %%
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
out_path_nolimits=os.path.join(fig_path,"iris_tree_nolimits.dot")

# %%
export_graphviz(tree_clf,
               out_file=out_path_nolimits,
               feature_names=iris.feature_names[2:],
               class_names=iris.target_names,
               rounded=True,
               filled=True
               )

# %%
# !dot -Tpng "figures/iris_tree_nolimits.dot" -o "figures/iris_tree_nolimits.png"

# %%
png_path2=os.path.join(fig_path,"iris_tree_nolimits.png")

# %%
Image(png_path2, width=600)

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg=DecisionTreeRegressor(max_depth=2)

# %%
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
out_path_reg=os.path.join(fig_path,"iris_tree_reg.dot")

# %%
export_graphviz(tree_reg,
               out_file=out_path_reg,
               feature_names=iris.feature_names[2:],
               class_names=iris.target_names,
               rounded=True,
               filled=True
               )

# %%
# !dot -Tpng "figures/iris_tree_reg.dot" -o "figures/iris_tree_reg.png"

# %%
fig_path3=os.path.join(fig_path,"iris_tree_reg.png")

# %%
Image(fig_path3)

# %%
tree_reg2=DecisionTreeRegressor()

# %%
tree_reg2.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %%
out_path_reg2=os.path.join(fig_path,"iris_tree_reg_nolimits.dot")

# %%
export_graphviz(tree_reg2,
               out_file=out_path_reg2,
               feature_names=iris.feature_names[2:],
               class_names=iris.target_names,
               rounded=True,
               filled=True
               )

# %%
# !dot -Tpng "figures\iris_tree_reg_nolimits.dot" -o "figures\iris_tree_reg_nolimits.png"

# %%
fig_path4=os.path.join(fig_path,"iris_tree_reg_nolimits.png")

# %%
Image(fig_path4,width=600)
